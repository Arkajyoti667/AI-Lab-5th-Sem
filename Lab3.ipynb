# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkajyoti667/AI-Lab-5th-Sem/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

graph = {
    'A': ['B'],
    'B': ['A', 'C'],
    'C': ['B'],
    'D': ['E'],
    'E': ['D'],
    'F': ['D'],
    'G': ['F']
}

def route_exists(graph, start, destination):

    visited = set()

    def dfs(city):

        if city == destination:
            return True

        visited.add(city)

        for neighbour in graph[city]:

            if neighbour not in visited:

                if dfs(neighbour):
                    return True

        return False

    return dfs(start)

def connected_components(graph):

    visited = set()
    components = []

    def dfs(city, component):

        visited.add(city)
        component.append(city)

        for neighbour in graph[city]:

            if neighbour not in visited:
                dfs(neighbour, component)

    for city in graph:

        if city not in visited:

            component = []

            dfs(city, component)

            components.append(component)

    return components

print("Route A to C:", route_exists(graph, 'A', 'C'))

print("Route A to E:", route_exists(graph, 'A', 'E'))

print("\nConnected Components:")

components = connected_components(graph)

for component in components:
    print(component)

G = nx.Graph()

for city in graph:

    for neighbour in graph[city]:

        G.add_edge(city, neighbour)


pos = {
    'A': (0, 2),
    'B': (1, 2),
    'C': (2, 2),
    'D': (0, 0),
    'E': (1, 0),
    'F': (0, -1),
    'G': (0, -2)
}


plt.figure(figsize=(8, 6))

nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=2000,
    font_size=15,
    font_weight='bold'
)

plt.title("Road Network Graph")

plt.axis('off')

plt.show()
# Out:
# Route A to C: True
# Route A to E: False
#
# Connected Components:
# ['A', 'B', 'C']
# ['D', 'E']
# ['F']
# ['G']
