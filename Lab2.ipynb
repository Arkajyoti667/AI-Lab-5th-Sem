# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkajyoti667/AI-Lab-5th-Sem/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

def water_jug():
    capacity_a = 4
    capacity_b = 3
    target = 2

    start = (0, 0)

    queue = deque()
    queue.append((start, []))

    visited = set()

    while queue:
        (a, b), path = queue.popleft()

        if (a, b) in visited:
            continue

        visited.add((a, b))
        path = path + [(a, b)]


        if a == target or b == target:
            print("Minimum Sequence of Steps:")

            for i, state in enumerate(path):
                print(i, ":", state)

            return

        states = []


        states.append((capacity_a, b))

        states.append((a, capacity_b))


        states.append((0, b))


        states.append((a, 0))


        amount = min(a, capacity_b - b)
        states.append((a - amount, b + amount))

        amount = min(b, capacity_a - a)
        states.append((a + amount, b - amount))

        for state in states:
            if state not in visited:
                queue.append((state, path))


water_jug()
# Out:
# Minimum Sequence of Steps:
# 0 : (0, 0)
# 1 : (0, 3)
# 2 : (3, 0)
# 3 : (3, 3)
# 4 : (4, 2)
